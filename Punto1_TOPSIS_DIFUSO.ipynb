# %%
import pandas as pand
import sympy as sp

# %% [markdown]
# Número de alternativas = 4
# Alternativas =
#
#
# Colombia Yappo          a1
#
# PCHogar                 a2
#
# Medmall                 a3
#
# eBay                    a4
#
# Número de criterios = 10
#
# Criterios =
#
#
# Eficiencia              c1      excelente
#
# prácticidad             c2      bueno
#
# fácilidad de uso        c3      malo
#
# ahorro de tiempo        c4      excelente
#
# comunicación            c5      malo
#
# Confianza               c6      muy bueno
#
# Seguridad               c7      bueno
#
# Familiar                c8      inaceptable
#
# Experiencia             c9      muy malo
#
# Competencia             c10     muy bueno

# %%
crit = ['Eficiencia', 'prácticidad', 'fácilidad de uso', 
        'ahorro de tiempo', 'comunicación', 'Confianza', 
        'Seguridad', 'Familiar', 'Experiencia', 'Competencia']
alt = ['Colombia Yappo', 'PCHogar', 'MedMall', 'eBay', '']
alt.append('pesos')

# %% [markdown]
# Escala de valores lingüistícos=
#
#
# inaceptable     :   [1.1.2]
#
# muy malo        :   [1,2,3]
#
# malo            :   [2,3,4]
#
# medio           :   [4,5,6]
#
# bueno           :   [6,7,8]
#
# muy bueno       :   [7,8,9]
#
# excelente       :   [8,9,9]

# %%
ColYa = ['bueno', 'malo', 'excelente', 'muy malo', 'muy bueno', 'muy bueno', 'medio', 'inaceptable', 'bueno', 'excelente']
PCH = ['medio', 'malo', 'excelente', 'excelente', 'inaceptable', 'muy bueno', 'medio', 'bueno', 'muy malo', 'muy bueno']
MMall = ['excelente', 'muy malo', 'muy malo', 'muy malo', 'muy bueno', 'medio', 'inaceptable', 'excelente', 'medio', 'bueno']
ebay = ['muy bueno', 'bueno', 'muy bueno', 'excelente', 'inaceptable', 'medio', 'excelente', 'bueno', 'malo', 'muy bueno']
sep = ['-','-','-','-','-','-','-','-','-','-',]
Pesos = ['excelente', 'bueno', 'malo', 'excelente', 'malo', 'muy bueno', 'bueno', 'inaceptable', 'muy malo', 'muy bueno']

# %%
MTfuzzy = [ColYa, PCH, MMall, ebay, sep, Pesos]
MTfuzzyFrame = pand.DataFrame(MTfuzzy, index= alt, columns= crit)  
display(MTfuzzyFrame)
# Out:
#                Eficiencia prácticidad fácilidad de uso ahorro de tiempo  \
# Colombia Yappo      bueno        malo        excelente         muy malo
# PCHogar             medio        malo        excelente        excelente
# MedMall         excelente    muy malo         muy malo         muy malo
# eBay            muy bueno       bueno        muy bueno        excelente
#                         -           -                -                -
# pesos           excelente       bueno             malo        excelente
#
#                comunicación  Confianza    Seguridad     Familiar Experiencia  \
# Colombia Yappo    muy bueno  muy bueno        medio  inaceptable       bueno
# PCHogar         inaceptable  muy bueno        medio        bueno    muy malo
# MedMall           muy bueno      medio  inaceptable    excelente       medio
# eBay            inaceptable      medio    excelente        bueno        malo
#                           -          -            -            -           -
# pesos                  malo  muy bueno        bueno  inaceptable    muy malo
#
#                Competencia
# Colombia Yappo   excelente
# PCHogar          muy bueno
# MedMall              bueno
# eBay             muy bueno
#                          -
# pesos            muy bueno

# %%
I = sp.Matrix([1,1,2])
MM = sp.Matrix([1,2,3])       
M = sp.Matrix([2,3,4])
H = sp.Matrix([4,5,6])
B = sp.Matrix([6,7,8])
MB = sp.Matrix([7,8,9])
E = sp.Matrix([8,9,9])

NTfuzzy = MTfuzzy
for i in range(0,6,1):
    for j in range(0,10,1):
        if MTfuzzy[i][j] == 'inaceptable':
            NTfuzzy[i][j] = I.T
        elif MTfuzzy[i][j] == 'muy malo':
            NTfuzzy[i][j] = MM.T
        elif MTfuzzy[i][j] == 'malo':
            NTfuzzy[i][j] = M.T
        elif MTfuzzy[i][j] == 'medio':
            NTfuzzy[i][j] = H.T
        elif MTfuzzy[i][j] == 'bueno':
            NTfuzzy[i][j] = B.T
        elif MTfuzzy[i][j] == 'muy bueno':
            NTfuzzy[i][j] = MB.T
        elif MTfuzzy[i][j] == 'excelente':
            NTfuzzy[i][j] = E.T
NTfuzzyFrame = pand.DataFrame(NTfuzzy, index= alt, columns= crit)  
display(NTfuzzyFrame)
# Out:
#                Eficiencia prácticidad fácilidad de uso ahorro de tiempo  \
# Colombia Yappo  [6, 7, 8]   [2, 3, 4]        [8, 9, 9]        [1, 2, 3]
# PCHogar         [4, 5, 6]   [2, 3, 4]        [8, 9, 9]        [8, 9, 9]
# MedMall         [8, 9, 9]   [1, 2, 3]        [1, 2, 3]        [1, 2, 3]
# eBay            [7, 8, 9]   [6, 7, 8]        [7, 8, 9]        [8, 9, 9]
#                         -           -                -                -
# pesos           [8, 9, 9]   [6, 7, 8]        [2, 3, 4]        [8, 9, 9]
#
#                comunicación  Confianza  Seguridad   Familiar Experiencia  \
# Colombia Yappo    [7, 8, 9]  [7, 8, 9]  [4, 5, 6]  [1, 1, 2]   [6, 7, 8]
# PCHogar           [1, 1, 2]  [7, 8, 9]  [4, 5, 6]  [6, 7, 8]   [1, 2, 3]
# MedMall           [7, 8, 9]  [4, 5, 6]  [1, 1, 2]  [8, 9, 9]   [4, 5, 6]
# eBay              [1, 1, 2]  [4, 5, 6]  [8, 9, 9]  [6, 7, 8]   [2, 3, 4]
#                           -          -          -          -           -
# pesos             [2, 3, 4]  [7, 8, 9]  [6, 7, 8]  [1, 1, 2]   [1, 2, 3]
#
#                Competencia
# Colombia Yappo   [8, 9, 9]
# PCHogar          [7, 8, 9]
# MedMall          [6, 7, 8]
# eBay             [7, 8, 9]
#                          -
# pesos            [7, 8, 9]

# %%
c = []
NormFuzzy = NTfuzzy
for i in range(0,10,1):
    c = []
    for j in range(0,4,1):
        c.append(NTfuzzy[j][i][0,2])
    c = max(c) 
    for k in range(0,4,1):
        NormFuzzy[k][i] = NTfuzzy[k][i]/c
NormFuzzyFrame = pand.DataFrame(NormFuzzy, index= alt, columns= crit)  
display(NormFuzzyFrame)
# Out:
#                      Eficiencia      prácticidad fácilidad de uso  \
# Colombia Yappo  [2/3, 7/9, 8/9]  [1/4, 3/8, 1/2]      [8/9, 1, 1]
# PCHogar         [4/9, 5/9, 2/3]  [1/4, 3/8, 1/2]      [8/9, 1, 1]
# MedMall             [8/9, 1, 1]  [1/8, 1/4, 3/8]  [1/9, 2/9, 1/3]
# eBay              [7/9, 8/9, 1]    [3/4, 7/8, 1]    [7/9, 8/9, 1]
#                               -                -                -
# pesos                 [8, 9, 9]        [6, 7, 8]        [2, 3, 4]
#
#                ahorro de tiempo     comunicación        Confianza  \
# Colombia Yappo  [1/9, 2/9, 1/3]    [7/9, 8/9, 1]    [7/9, 8/9, 1]
# PCHogar             [8/9, 1, 1]  [1/9, 1/9, 2/9]    [7/9, 8/9, 1]
# MedMall         [1/9, 2/9, 1/3]    [7/9, 8/9, 1]  [4/9, 5/9, 2/3]
# eBay                [8/9, 1, 1]  [1/9, 1/9, 2/9]  [4/9, 5/9, 2/3]
#                               -                -                -
# pesos                 [8, 9, 9]        [2, 3, 4]        [7, 8, 9]
#
#                       Seguridad         Familiar      Experiencia  \
# Colombia Yappo  [4/9, 5/9, 2/3]  [1/9, 1/9, 2/9]    [3/4, 7/8, 1]
# PCHogar         [4/9, 5/9, 2/3]  [2/3, 7/9, 8/9]  [1/8, 1/4, 3/8]
# MedMall         [1/9, 1/9, 2/9]      [8/9, 1, 1]  [1/2, 5/8, 3/4]
# eBay                [8/9, 1, 1]  [2/3, 7/9, 8/9]  [1/4, 3/8, 1/2]
#                               -                -                -
# pesos                 [6, 7, 8]        [1, 1, 2]        [1, 2, 3]
#
#                     Competencia
# Colombia Yappo      [8/9, 1, 1]
# PCHogar           [7/9, 8/9, 1]
# MedMall         [2/3, 7/9, 8/9]
# eBay              [7/9, 8/9, 1]
#                               -
# pesos                 [7, 8, 9]

# %%
PondFuzzy = NormFuzzy
for i in range(0,10,1):
    for j in range(0,4,1):
        for k in range(0,3,1):
            PondFuzzy[j][i][0,k] = NormFuzzy[j][i][0,k] * NormFuzzy[5][i][0,k]

PondFuzzyFrame = pand.DataFrame(PondFuzzy, index= alt, columns= crit)  
display(PondFuzzyFrame)
# Out:
#                   Eficiencia     prácticidad fácilidad de uso  \
# Colombia Yappo  [16/3, 7, 8]  [3/2, 21/8, 4]     [16/9, 3, 4]
# PCHogar         [32/9, 5, 6]  [3/2, 21/8, 4]     [16/9, 3, 4]
# MedMall         [64/9, 9, 9]   [3/4, 7/4, 3]  [2/9, 2/3, 4/3]
# eBay            [56/9, 8, 9]  [9/2, 49/8, 8]   [14/9, 8/3, 4]
#                            -               -                -
# pesos              [8, 9, 9]       [6, 7, 8]        [2, 3, 4]
#
#                ahorro de tiempo     comunicación        Confianza  \
# Colombia Yappo      [8/9, 2, 3]   [14/9, 8/3, 4]  [49/9, 64/9, 9]
# PCHogar            [64/9, 9, 9]  [2/9, 1/3, 8/9]  [49/9, 64/9, 9]
# MedMall             [8/9, 2, 3]   [14/9, 8/3, 4]  [28/9, 40/9, 6]
# eBay               [64/9, 9, 9]  [2/9, 1/3, 8/9]  [28/9, 40/9, 6]
#                               -                -                -
# pesos                 [8, 9, 9]        [2, 3, 4]        [7, 8, 9]
#
#                         Seguridad          Familiar      Experiencia  \
# Colombia Yappo  [8/3, 35/9, 16/3]   [1/9, 1/9, 4/9]    [3/4, 7/4, 3]
# PCHogar         [8/3, 35/9, 16/3]  [2/3, 7/9, 16/9]  [1/8, 1/2, 9/8]
# MedMall          [2/3, 7/9, 16/9]       [8/9, 1, 2]  [1/2, 5/4, 9/4]
# eBay                 [16/3, 7, 8]  [2/3, 7/9, 16/9]  [1/4, 3/4, 3/2]
#                                 -                 -                -
# pesos                   [6, 7, 8]         [1, 1, 2]        [1, 2, 3]
#
#                     Competencia
# Colombia Yappo     [56/9, 8, 9]
# PCHogar         [49/9, 64/9, 9]
# MedMall         [14/3, 56/9, 8]
# eBay            [49/9, 64/9, 9]
#                               -
# pesos                 [7, 8, 9]

# %%
A = [[],[]]
for i in range(0,10,1):
    c = []
    ind = 0
    for j in range(0,4,1):
        c.append(PondFuzzy[j][i][0,2])
    c = max(c)
    cont = []
    for j in range(0,4,1):
        if c == PondFuzzy[j][i][0,2]:
            cont.append(j)
    if len(cont) > 1:
        c = []
        for k in cont:
            c.append(PondFuzzy[k][i][0,1])
        c = max(c)
        cont = []
        for j in range(0,4,1):
            if c == PondFuzzy[j][i][0,1]:
                cont.append(j)
        if len(cont) > 1:
            c = []
            for k in cont:
                c.append(PondFuzzy[k][i][0,0])
            c = max(c)
            for k in cont:
                if PondFuzzy[k][i][0,0] == c:
                    ind = k
        elif len(cont) == 1:
            ind = cont[0]
    elif len(cont) == 1:
        ind = cont[0]
    A[0].append(PondFuzzy[ind][i])
for i in range(0,10,1):
    c = []
    ind = 0
    for j in range(0,4,1):
        c.append(PondFuzzy[j][i][0,2])
    c = min(c)
    cont = []
    for j in range(0,4,1):
        if c == PondFuzzy[j][i][0,2]:
            cont.append(j)
    if len(cont) > 1:
        c = []
        for k in cont:
            c.append(PondFuzzy[k][i][0,1])
        c = min(c)
        cont = []
        for j in range(0,4,1):
            if c == PondFuzzy[j][i][0,1]:
                cont.append(j)
        if len(cont) > 1:
            c = []
            for k in cont:
                c.append(PondFuzzy[k][i][0,0])
            c = min(c)
            for k in cont:
                if PondFuzzy[k][i][0,0] == c:
                    ind = k
        elif len(cont) == 1:
            ind = cont[0]
    elif len(cont) == 1:
        ind = cont[0]
    A[1].append(PondFuzzy[ind][i])
id = ['ideal', 'no ideal']
AFrame = pand.DataFrame(A, index = id, columns = crit)
display(AFrame)
# Out:
#             Eficiencia     prácticidad fácilidad de uso ahorro de tiempo  \
# ideal     [64/9, 9, 9]  [9/2, 49/8, 8]     [16/9, 3, 4]     [64/9, 9, 9]
# no ideal  [32/9, 5, 6]   [3/4, 7/4, 3]  [2/9, 2/3, 4/3]      [8/9, 2, 3]
#
#              comunicación        Confianza         Seguridad         Familiar  \
# ideal      [14/9, 8/3, 4]  [49/9, 64/9, 9]      [16/3, 7, 8]      [8/9, 1, 2]
# no ideal  [2/9, 1/3, 8/9]  [28/9, 40/9, 6]  [2/3, 7/9, 16/9]  [1/9, 1/9, 4/9]
#
#               Experiencia      Competencia
# ideal       [3/4, 7/4, 3]     [56/9, 8, 9]
# no ideal  [1/8, 1/2, 9/8]  [14/3, 56/9, 8]

# %%
Dideal = sp.zeros(4,10)
Dnoideal = sp.zeros(4,10)
for i in range(0,10,1):
    for j in range(0,4,1):
        di = 0
        dn = 0
        for k in range(0,3):
            di = di + (PondFuzzy[j][i][0,k] - A[0][i][0,k])**2
            dn = dn + (PondFuzzy[j][i][0,k] - A[1][i][0,k])**2
        Dideal[j,i] = di**(1/2)
        Dnoideal[j,i] = dn**(1/2)
alt.pop(5)
alt.pop(4)
DidealList = Dideal.tolist()
DnoidealList = Dnoideal.tolist()
DidealFrame = pand.DataFrame(DidealList, index = alt, columns = crit)
DnoidealFrame = pand.DataFrame(DnoidealList, index = alt, columns = crit)
display(DidealFrame)
display(DnoidealFrame)
# Out:
#                       Eficiencia       prácticidad   fácilidad de uso  \
# Colombia Yappo  2.85665780715165  6.10327780786685                  0
# PCHogar         6.13530564101268  6.10327780786685                  0
# MedMall                        0  7.62909725983356   3.86979439272622
# eBay            1.33795495319914                 0  0.400616808384888
#
#                 ahorro de tiempo      comunicación         Confianza  \
# Colombia Yappo  11.1227716592006                 0                 0
# PCHogar                        0  4.11111111111111                 0
# MedMall         11.1227716592006                 0  4.64279609239471
# eBay                           0  4.11111111111111  4.64279609239471
#
#                        Seguridad           Familiar        Experiencia  \
# Colombia Yappo  4.88888888888889   1.95315509236077                  0
# PCHogar         4.88888888888889  0.384900179459751   2.33853586673371
# MedMall         9.96041548045110                  0  0.935414346693485
# eBay                           0  0.384900179459751   1.87082869338697
#
#                      Competencia
# Colombia Yappo                 0
# PCHogar         1.18112731252607
# MedMall         2.56519919569227
# eBay            1.18112731252607
#                       Eficiencia       prácticidad  fácilidad de uso  \
# Colombia Yappo  3.34073252852731  1.52581945196671  3.86979439272622
# PCHogar                        0  1.52581945196671  3.86979439272622
# MedMall         6.13530564101268                 0                 0
# eBay            5.01109879279097  7.62909725983356  3.59010987142300
#
#                 ahorro de tiempo      comunicación         Confianza  \
# Colombia Yappo                 0  4.11111111111111  4.64279609239471
# PCHogar         11.1227716592006                 0  4.64279609239471
# MedMall                        0  4.11111111111111                 0
# eBay            11.1227716592006                 0                 0
#
#                        Seguridad          Familiar        Experiencia  \
# Colombia Yappo  5.13039839138453                 0   2.33853586673371
# PCHogar         5.13039839138453  1.59086900703071                  0
# MedMall                        0  1.95315509236077   1.40312152004023
# eBay            9.96041548045110  1.59086900703071  0.467707173346743
#
#                      Competencia
# Colombia Yappo  2.56519919569227
# PCHogar         1.54759869746490
# MedMall                        0
# eBay            1.54759869746490

# %%
Dalt = sp.zeros(4,2)
for i in range(0,4,1):
    dideal = 0
    dnoideal = 0
    for j in range(0,10,1):
        dideal = dideal + Dideal[i,j] 
        dnoideal = dnoideal + Dnoideal[i,j]
    Dalt[i,0] = dideal
    Dalt[i,1] = dnoideal
DaltList = Dalt.tolist()
DaltListFrame = pand.DataFrame(DaltList, index = alt, columns = id)
display(DaltListFrame)
# Out:
#                            ideal          no ideal
# Colombia Yappo  26.9247512554688  27.5243870305366
# PCHogar         25.1431468075991  29.4300476921684
# MedMall         40.7254884269919  13.6026933645248
# eBay            13.9293351504626  40.9196679415416

# %%
CC = sp.zeros(4,1)
for i in range(0,4,1):
    CC[i,0] = Dalt[i,1]/(Dalt[i,1]+Dalt[i,0])

CCList = CC.tolist()
CCListFrame = pand.DataFrame(CCList, index = alt, columns = ['Coeficiente de Cercanía'])
CCListFrame = CCListFrame.sort_values(by = 'Coeficiente de Cercanía', ascending = False)
display(CCListFrame)
# Out:
#                Coeficiente de Cercanía
# eBay                 0.746042145431569
# PCHogar              0.539276616696752
# Colombia Yappo       0.505506384434572
# MedMall              0.250380059040533
