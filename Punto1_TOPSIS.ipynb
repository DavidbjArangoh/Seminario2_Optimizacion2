# %%
import random as rand
import pandas as pand 
import sympy as sym

# %% [markdown]
# Número de alternativas = 4
# Alternativas =
#
#
# Colombia Yappo          a1
#
# PCHogar                 a2
#
# Medmall                 a3
#
# eBay                    a4
#
# Número de criterios = 10
#
# Criterios =
#
#
#
# Eficiencia              c1 =0,3
#
# prácticidad             c2 =0,05
#
# fácilidad de uso        c3 =0,05
#
# ahorro de tiempo        c4 =0,05
#
# comunicación            c5 =0,025
#
# Confianza               c6 =0,1
#
# Seguridad               c7 =0,3
#
# Familiar                c8 =0,02
#
# Experiencia             c9 =0,075
#
# Competencia             c10 =0,03

# %%
crit = []
for i in range(1,11,1):
    crit.append('criterio_'+ str(i))

alt = ['Colombia Yappo', 'PCHogar', 'MedMall', 'eBay']
alt.append('pesos')

# %%
MTopsis = sym.zeros(5,10)
for i in range(0,10,1):
    for j in range(0,4,1):
        MTopsis[j,i] = rand.randrange(0,100)

pesos = [0.3, 0.05, 0.05, 0.05, 0.025, 0.1, 0.3, 0.02, 0.075, 0.03]
for i in range(0,10,1):
    MTopsis[4,i] = pesos[i]

ATopsis = MTopsis.tolist()
MTopsisFrame = pand.DataFrame(ATopsis, index = alt ,columns = crit)
display(MTopsisFrame)
# Out:
#                        criterio_1          criterio_2          criterio_3  \
# Colombia Yappo                 22                  44                  54
# PCHogar                        15                  28                  49
# MedMall                        12                  10                  23
# eBay                           50                  59                  30
# pesos           0.300000000000000  0.0500000000000000  0.0500000000000000
#
#                         criterio_4          criterio_5         criterio_6  \
# Colombia Yappo                  10                   8                 11
# PCHogar                          9                  26                 97
# MedMall                         10                   7                 73
# eBay                            35                  50                 83
# pesos           0.0500000000000000  0.0250000000000000  0.100000000000000
#
#                        criterio_7          criterio_8          criterio_9  \
# Colombia Yappo                 29                  83                  95
# PCHogar                        36                  23                  71
# MedMall                        20                  45                  75
# eBay                           50                  10                  22
# pesos           0.300000000000000  0.0200000000000000  0.0750000000000000
#
#                        criterio_10
# Colombia Yappo                  26
# PCHogar                         37
# MedMall                         80
# eBay                            27
# pesos           0.0300000000000000

# %%
VTopsis = MTopsis
norm = 0
for j in range(0,10,1):
    norm = 0
    for i in range(0,4,1):
        norm = norm + MTopsis[i,j]**2
    norm = norm**(1/2)
    for k in range(0,4,1):
        VTopsis[k,j] = MTopsis[k,j]/norm

ATopsis = VTopsis.tolist()
VTopsisFrame = pand.DataFrame(ATopsis, index = alt ,columns = crit)
display(VTopsisFrame)
# Out:
#                        criterio_1          criterio_2          criterio_3  \
# Colombia Yappo  0.379932026507218   0.554303903119194   0.657461901400876
# PCHogar         0.259044563527649   0.352738847439487   0.596585799419314
# MedMall         0.207235650822119   0.125978159799817   0.280030069115188
# eBay            0.863481878425495   0.743271142818919   0.365256611889376
# pesos           0.300000000000000  0.0500000000000000  0.0500000000000000
#
#                         criterio_4          criterio_5          criterio_6  \
# Colombia Yappo   0.257684036015037   0.139494810181231  0.0745904149214948
# PCHogar          0.231915632413533   0.453358133089001   0.657751840671363
# MedMall          0.257684036015037   0.122057958908577   0.495009117206284
# eBay             0.901894126052628   0.871842563632695   0.562818585316733
# pesos           0.0500000000000000  0.0250000000000000   0.100000000000000
#
#                        criterio_7          criterio_8          criterio_9  \
# Colombia Yappo  0.408612852188955   0.849641330716916   0.668831676618325
# PCHogar         0.507243540648357   0.235442778391435   0.499863674104222
# MedMall         0.281801967026865   0.460648914244111   0.528025007856572
# eBay            0.704504917567163   0.102366425387580   0.154887335637928
# pesos           0.300000000000000  0.0200000000000000  0.0750000000000000
#
#                        criterio_10
# Colombia Yappo   0.271452583964827
# PCHogar          0.386297907949946
# MedMall          0.835238719891776
# eBay             0.281893067963474
# pesos           0.0300000000000000

# %%
WTopsis = VTopsis
for i in range(0,10,1):
    for j in range(0,4,1):
        WTopsis[j,i] = VTopsis[j,i]*VTopsis[4,i]

ATopsis = WTopsis.tolist()
WTopsisFrame = pand.DataFrame(ATopsis, index = alt ,columns = crit)
display(WTopsisFrame)
# Out:
#                         criterio_1           criterio_2          criterio_3  \
# Colombia Yappo   0.113979607952165   0.0277151951559597  0.0328730950700438
# PCHogar         0.0777133690582946   0.0176369423719743  0.0298292899709657
# MedMall         0.0621706952466356  0.00629890798999084  0.0140015034557594
# eBay             0.259044563527649   0.0371635571409459  0.0182628305944688
# pesos            0.300000000000000   0.0500000000000000  0.0500000000000000
#
#                         criterio_4           criterio_5           criterio_6  \
# Colombia Yappo  0.0128842018007518  0.00348737025453078  0.00745904149214948
# PCHogar         0.0115957816206766   0.0113339533272250   0.0657751840671363
# MedMall         0.0128842018007518  0.00305144897271443   0.0495009117206284
# eBay            0.0450947063026314   0.0217960640908174   0.0562818585316733
# pesos           0.0500000000000000   0.0250000000000000    0.100000000000000
#
#                         criterio_7           criterio_8          criterio_9  \
# Colombia Yappo   0.122583855656686   0.0169928266143383  0.0501623757463744
# PCHogar          0.152173062194507  0.00470885556782869  0.0374897755578166
# MedMall         0.0845405901080596  0.00921297828488222  0.0396018755892429
# eBay             0.211351475270149  0.00204732850775161  0.0116165501728446
# pesos            0.300000000000000   0.0200000000000000  0.0750000000000000
#
#                         criterio_10
# Colombia Yappo  0.00814357751894482
# PCHogar          0.0115889372384984
# MedMall          0.0250571615967533
# eBay            0.00845679203890423
# pesos            0.0300000000000000

# %%
A = sym.zeros(2,10)
for i in range(0,10,1):
    A[0,i] = max(WTopsis[0:4,i].tolist())
    A[1,i] = min(WTopsis[0:4,i].tolist())
ind = ['ideal', 'no-ideal']

ATopsis = A.tolist()
idealFrame = pand.DataFrame(ATopsis, index = ind ,columns = crit)
display(idealFrame)
# Out:
#                   criterio_1           criterio_2          criterio_3  \
# ideal      0.259044563527649   0.0371635571409459  0.0328730950700438
# no-ideal  0.0621706952466356  0.00629890798999084  0.0140015034557594
#
#                   criterio_4           criterio_5           criterio_6  \
# ideal     0.0450947063026314   0.0217960640908174   0.0657751840671363
# no-ideal  0.0115957816206766  0.00305144897271443  0.00745904149214948
#
#                   criterio_7           criterio_8          criterio_9  \
# ideal      0.211351475270149   0.0169928266143383  0.0501623757463744
# no-ideal  0.0845405901080596  0.00204732850775161  0.0116165501728446
#
#                   criterio_10
# ideal      0.0250571615967533
# no-ideal  0.00814357751894482

# %%
distancias = sym.zeros(4,2)
d_plus = 0
d_minus = 0
for i in range(0,4,1):
    d_plus = 0
    d_minus = 0
    for j in range(0,10,1):
        d_plus = d_plus + (A[0,j]-WTopsis[i,j])**2
        d_minus = d_minus + (A[1,j]-WTopsis[i,j])**2
    distancias[i,0] = d_plus**(1/2)
    distancias[i,1] = d_minus**(1/2)

alt.pop(4)
ATopsis = distancias.tolist()
distancesFrame = pand.DataFrame(ATopsis, index = alt, columns = ind)
display(distancesFrame)
# Out:
#                              ideal            no-ideal
# Colombia Yappo   0.184587025149647  0.0815919509025703
# PCHogar          0.196209473827598  0.0967085633451176
# MedMall          0.240779699071554  0.0537566105759653
# eBay            0.0478362196460449   0.244271181684415

# %%
RS = sym.zeros(4,1)
for i in range(0,4,1):
    RS[i,0] = distancias[i,1]/(distancias[i,0]+distancias[i,1])

ATopsis = RS.tolist()
RSFrame = pand.DataFrame(ATopsis, index = alt, columns = ['Eficiencia'])
RSFrame = RSFrame.sort_values(by = 'Eficiencia', ascending = False)
display(RSFrame)
# Out:
#                        Eficiencia
# eBay            0.836237563895452
# PCHogar         0.330155712767168
# Colombia Yappo  0.306530410901288
# MedMall         0.182512677775781
