# %%
import random as rand
import pandas as pand 
import sympy as sym

# %% [markdown]
# Número de alternativas = 4
# Alternativas =
#
#
# Colombia Yappo          a1
#
# PCHogar                 a2
#
# Medmall                 a3
#
# eBay                    a4
#
# Número de criterios = 10
#
# Criterios =
#
#
#
# Eficiencia              c1 = 0,3
#
# prácticidad             c2 = 0,05
#
# fácilidad de uso        c3 = 0,05
#
# ahorro de tiempo        c4 = 0,05
#
# comunicación            c5 = 0,025
#
# Confianza               c6 = 0,1
#
# Seguridad               c7 = 0,3
#
# Familiar                c8 = 0,02
#
# Experiencia             c9 = 0,075
#
# Competencia             c10 = 0,03

# %%
crit = ['Eficiencia', 'prácticidad', 'fácilidad de uso', 
        'ahorro de tiempo', 'comunicación', 'Confianza', 
        'Seguridad', 'Familiar', 'Experiencia', 'Competencia']

alt = ['Colombia Yappo', 'PCHogar', 'MedMall', 'eBay']
alt.append('pesos')

alt1 = []
for i in range(0,4,1):
        alt1.append('A'+str(i+1))
alt1.append('W')
crit1 = []
for i in range(0,10,1):
        crit1.append('C'+str(i+1))

# %%
ColYa = [7, 3, 9, 2, 8, 8, 4, 1, 7, 9]
PCH = [4, 3, 9, 9, 1, 8, 5, 7, 2, 8]
MMall = [9, 2, 2, 2, 8, 5, 1, 9, 6, 7]
ebay = [8, 7, 8, 9, 1, 6, 9, 7, 3, 8]
pesos = [0.3, 0.05, 0.05, 0.05, 0.025, 0.1, 0.3, 0.02, 0.075, 0.03]

ColYaFrame = pand.DataFrame(ColYa, index = crit, columns = ['Colombia Yappo'])
PCHFrame = pand.DataFrame(PCH, index = crit, columns = ['PCHogar'])
MMallFrame = pand.DataFrame(MMall, index = crit, columns = ['Medmall'])
ebayFrame = pand.DataFrame(ebay, index = crit, columns = ['ebay'])
pesosFrame = pand.DataFrame(pesos, index = crit, columns = ['pesos'])

display(ColYaFrame)
display(PCHFrame)
display(MMallFrame)
display(ebayFrame)
display(pesosFrame)

#print(ColYaFrame.to_latex())
#print(PCHFrame.to_latex())
#print(MMallFrame.to_latex())
#print(ebayFrame.to_latex())
#print(pesosFrame.to_latex())
# Out:
#                   Colombia Yappo
# Eficiencia                     7
# prácticidad                    3
# fácilidad de uso               9
# ahorro de tiempo               2
# comunicación                   8
# Confianza                      8
# Seguridad                      4
# Familiar                       1
# Experiencia                    7
# Competencia                    9
#                   PCHogar
# Eficiencia              4
# prácticidad             3
# fácilidad de uso        9
# ahorro de tiempo        9
# comunicación            1
# Confianza               8
# Seguridad               5
# Familiar                7
# Experiencia             2
# Competencia             8
#                   Medmall
# Eficiencia              9
# prácticidad             2
# fácilidad de uso        2
# ahorro de tiempo        2
# comunicación            8
# Confianza               5
# Seguridad               1
# Familiar                9
# Experiencia             6
# Competencia             7
#                   ebay
# Eficiencia           8
# prácticidad          7
# fácilidad de uso     8
# ahorro de tiempo     9
# comunicación         1
# Confianza            6
# Seguridad            9
# Familiar             7
# Experiencia          3
# Competencia          8
#                   pesos
# Eficiencia        0.300
# prácticidad       0.050
# fácilidad de uso  0.050
# ahorro de tiempo  0.050
# comunicación      0.025
# Confianza         0.100
# Seguridad         0.300
# Familiar          0.020
# Experiencia       0.075
# Competencia       0.030
# \begin{tabular}{lr}
# \toprule
# {} &  pesos \\
# \midrule
# Eficiencia       &  0.300 \\
# prácticidad      &  0.050 \\
# fácilidad de uso &  0.050 \\
# ahorro de tiempo &  0.050 \\
# comunicación     &  0.025 \\
# Confianza        &  0.100 \\
# Seguridad        &  0.300 \\
# Familiar         &  0.020 \\
# Experiencia      &  0.075 \\
# Competencia      &  0.030 \\
# \bottomrule
# \end{tabular}
# /var/folders/10/5kfk0wz54x52kqhv26ssv6hh0000gn/T/ipykernel_1496/2875451858.py:23: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(pesosFrame.to_latex())

# %%
MTopsis = sym.zeros(5,10)
for i in range(0,10,1):
    MTopsis[0,i] = ColYa[i]
    MTopsis[1,i] = PCH[i] 
    MTopsis[2,i] = MMall[i]
    MTopsis[3,i] = ebay[i]
    MTopsis[4,i] = pesos[i]

ATopsis = MTopsis.tolist()
MTopsisFrame = pand.DataFrame(ATopsis, index = alt1 ,columns = crit1)
display(MTopsisFrame)
print(MTopsisFrame.to_latex())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/samueldavidbenjacobarangohenao/Library/Mobile Documents/com~apple~CloudDocs/Hard Drive/EAFIT/Optimización_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb Cell 5' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/samueldavidbenjacobarangohenao/Library/Mobile%20Documents/com~apple~CloudDocs/Hard%20Drive/EAFIT/Optimizaci%C3%B3n_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb#ch0000003?line=6'>7</a>     MTopsis[4,i] = pesos[i]
#       <a href='vscode-notebook-cell:/Users/samueldavidbenjacobarangohenao/Library/Mobile%20Documents/com~apple~CloudDocs/Hard%20Drive/EAFIT/Optimizaci%C3%B3n_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb#ch0000003?line=8'>9</a> ATopsis = MTopsis.tolist()
# ---> <a href='vscode-notebook-cell:/Users/samueldavidbenjacobarangohenao/Library/Mobile%20Documents/com~apple~CloudDocs/Hard%20Drive/EAFIT/Optimizaci%C3%B3n_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb#ch0000003?line=9'>10</a> MTopsisFrame = pand.DataFrame(ATopsis, index = alt1 ,columns = crit1)
#      <a href='vscode-notebook-cell:/Users/samueldavidbenjacobarangohenao/Library/Mobile%20Documents/com~apple~CloudDocs/Hard%20Drive/EAFIT/Optimizaci%C3%B3n_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb#ch0000003?line=10'>11</a> display(MTopsisFrame)
#      <a href='vscode-notebook-cell:/Users/samueldavidbenjacobarangohenao/Library/Mobile%20Documents/com~apple~CloudDocs/Hard%20Drive/EAFIT/Optimizaci%C3%B3n_2/Seminary2/Seminario2_Optimizacion2/Punto1_TOPSIS.ipynb#ch0000003?line=11'>12</a> print(MTopsisFrame.to_latex())
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:729, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=719'>720</a>         columns = ensure_index(columns)  # type: ignore[arg-type]
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=720'>721</a>     arrays, columns, index = nested_data_to_arrays(
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=721'>722</a>         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=722'>723</a>         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=726'>727</a>         dtype,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=727'>728</a>     )
# --> <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=728'>729</a>     mgr = arrays_to_mgr(
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=729'>730</a>         arrays,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=730'>731</a>         columns,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=731'>732</a>         index,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=732'>733</a>         dtype=dtype,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=733'>734</a>         typ=manager,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=734'>735</a>     )
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=735'>736</a> else:
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=736'>737</a>     mgr = ndarray_to_mgr(
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=737'>738</a>         data,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=738'>739</a>         index,
#    (...)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=742'>743</a>         typ=manager,
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py?line=743'>744</a>     )
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py:125, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=121'>122</a>         index = ensure_index(index)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=123'>124</a>     # don't force copy because getting jammed in an ndarray anyway
# --> <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=124'>125</a>     arrays = _homogenize(arrays, index, dtype)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=125'>126</a>     # _homogenize ensures
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=126'>127</a>     #  - all(len(x) == len(index) for x in arrays)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=127'>128</a>     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=130'>131</a>
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=131'>132</a> else:
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=132'>133</a>     index = ensure_index(index)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py:628, in _homogenize(data, index, dtype)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=622'>623</a>             val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=624'>625</a>         val = sanitize_array(
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=625'>626</a>             val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=626'>627</a>         )
# --> <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=627'>628</a>         com.require_length_match(val, index)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=629'>630</a>     homogenized.append(val)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/construction.py?line=631'>632</a> return homogenized
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=552'>553</a> """
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=553'>554</a> Check the length of data matches the length of the index.
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=554'>555</a> """
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=555'>556</a> if len(data) != len(index):
# --> <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=556'>557</a>     raise ValueError(
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=557'>558</a>         "Length of values "
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=558'>559</a>         f"({len(data)}) "
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=559'>560</a>         "does not match length of index "
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=560'>561</a>         f"({len(index)})"
#     <a href='file:///Users/samueldavidbenjacobarangohenao/Library/Python/3.8/lib/python/site-packages/pandas/core/common.py?line=561'>562</a>     )
#
# ValueError: Length of values (5) does not match length of index (4)

# %%
VTopsis = MTopsis
norm = 0
for j in range(0,10,1):
    norm = 0
    for i in range(0,4,1):
        norm = norm + MTopsis[i,j]**2
    norm = norm**(1/2)
    for k in range(0,4,1):
        VTopsis[k,j] = MTopsis[k,j]/norm

ATopsis = VTopsis.tolist()
VTopsisFrame = pand.DataFrame(ATopsis, index = alt ,columns = crit)
display(VTopsisFrame)
# Out:
#                        Eficiencia         prácticidad    fácilidad de uso  \
# Colombia Yappo  0.483045891539648   0.356034497458156   0.593442426056208
# PCHogar         0.276026223736942   0.356034497458156   0.593442426056208
# MedMall         0.621059003408119   0.237356331638771   0.131876094679157
# eBay            0.552052447473883   0.830747160735697   0.527504378716630
# pesos           0.300000000000000  0.0500000000000000  0.0500000000000000
#
#                   ahorro de tiempo        comunicación          Confianza  \
# Colombia Yappo   0.153392997769474   0.701646415445623  0.581914373962646
# PCHogar          0.690268489962633  0.0877058019307029  0.581914373962646
# MedMall          0.153392997769474   0.701646415445623  0.363696483726654
# eBay             0.690268489962633  0.0877058019307029  0.436435780471985
# pesos           0.0500000000000000  0.0250000000000000  0.100000000000000
#
#                          Seguridad            Familiar         Experiencia  \
# Colombia Yappo   0.360667853866973  0.0745355992499930   0.707106781186547
# PCHogar          0.450834817333716   0.521749194749951   0.202030508910442
# MedMall         0.0901669634667432   0.670820393249937   0.606091526731326
# eBay             0.811502671200689   0.521749194749951   0.303045763365663
# pesos            0.300000000000000  0.0200000000000000  0.0750000000000000
#
#                        Competencia
# Colombia Yappo   0.560315525728221
# PCHogar          0.498058245091752
# MedMall          0.435800964455283
# eBay             0.498058245091752
# pesos           0.0300000000000000

# %%
WTopsis = VTopsis
for i in range(0,10,1):
    for j in range(0,4,1):
        WTopsis[j,i] = VTopsis[j,i]*VTopsis[4,i]

ATopsis = WTopsis.tolist()
WTopsisFrame = pand.DataFrame(ATopsis, index = alt ,columns = crit)
display(WTopsisFrame)
# Out:
#                         Eficiencia         prácticidad     fácilidad de uso  \
# Colombia Yappo   0.144913767461894  0.0178017248729078   0.0296721213028104
# PCHogar         0.0828078671210825  0.0178017248729078   0.0296721213028104
# MedMall          0.186317701022436  0.0118678165819385  0.00659380473395787
# eBay             0.165615734242165  0.0415373580367849   0.0263752189358315
# pesos            0.300000000000000  0.0500000000000000   0.0500000000000000
#
#                    ahorro de tiempo         comunicación           Confianza  \
# Colombia Yappo  0.00766964988847370   0.0175411603861406  0.0581914373962646
# PCHogar          0.0345134244981317  0.00219264504826757  0.0581914373962646
# MedMall         0.00766964988847370   0.0175411603861406  0.0363696483726654
# eBay             0.0345134244981317  0.00219264504826757  0.0436435780471985
# pesos            0.0500000000000000   0.0250000000000000   0.100000000000000
#
#                          Seguridad             Familiar         Experiencia  \
# Colombia Yappo   0.108200356160092  0.00149071198499986  0.0530330085889911
# PCHogar          0.135250445200115   0.0104349838949990  0.0151522881682832
# MedMall         0.0270500890400230   0.0134164078649987  0.0454568645048495
# eBay             0.243450801360207   0.0104349838949990  0.0227284322524247
# pesos            0.300000000000000   0.0200000000000000  0.0750000000000000
#
#                        Competencia
# Colombia Yappo  0.0168094657718466
# PCHogar         0.0149417473527526
# MedMall         0.0130740289336585
# eBay            0.0149417473527526
# pesos           0.0300000000000000

# %%
A = sym.zeros(2,10)
for i in range(0,10,1):
    A[0,i] = max(WTopsis[0:4,i].tolist())
    A[1,i] = min(WTopsis[0:4,i].tolist())
ind = ['ideal', 'no-ideal']

ATopsis = A.tolist()
idealFrame = pand.DataFrame(ATopsis, index = ind ,columns = crit)
display(idealFrame)
# Out:
#                   Eficiencia         prácticidad     fácilidad de uso  \
# ideal      0.186317701022436  0.0415373580367849   0.0296721213028104
# no-ideal  0.0828078671210825  0.0118678165819385  0.00659380473395787
#
#              ahorro de tiempo         comunicación           Confianza  \
# ideal      0.0345134244981317   0.0175411603861406  0.0581914373962646
# no-ideal  0.00766964988847370  0.00219264504826757  0.0363696483726654
#
#                    Seguridad             Familiar         Experiencia  \
# ideal      0.243450801360207   0.0134164078649987  0.0530330085889911
# no-ideal  0.0270500890400230  0.00149071198499986  0.0151522881682832
#
#                  Competencia
# ideal     0.0168094657718466
# no-ideal  0.0130740289336585

# %%
distancias = sym.zeros(4,2)
d_plus = 0
d_minus = 0
for i in range(0,4,1):
    d_plus = 0
    d_minus = 0
    for j in range(0,10,1):
        d_plus = d_plus + (A[0,j]-WTopsis[i,j])**2
        d_minus = d_minus + (A[1,j]-WTopsis[i,j])**2
    distancias[i,0] = d_plus**(1/2)
    distancias[i,1] = d_minus**(1/2)

alt.pop(4)
ATopsis = distancias.tolist()
distancesFrame = pand.DataFrame(ATopsis, index = alt, columns = ind)
display(distancesFrame)
# Out:
#                              ideal           no-ideal
# Colombia Yappo   0.146400680942137  0.114764970880886
# PCHogar          0.157060135721313  0.116427677637262
# MedMall          0.222509075854259  0.109592208694431
# eBay            0.0426310067489221  0.236373394880375

# %%
RS = sym.zeros(4,1)
for i in range(0,4,1):
    RS[i,0] = distancias[i,1]/(distancias[i,0]+distancias[i,1])

ATopsis = RS.tolist()
RSFrame = pand.DataFrame(ATopsis, index = alt, columns = ['Coeficiente de cercanía'])
RSFrame = RSFrame.sort_values(by = 'Coeficiente de cercanía', ascending = False)
display(RSFrame)
# Out:
#                Coeficiente de cercanía
# eBay                 0.847203103248656
# Colombia Yappo       0.439433631795713
# PCHogar              0.425714316873825
# MedMall              0.329996340855355
